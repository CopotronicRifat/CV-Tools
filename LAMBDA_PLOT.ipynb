# %% [markdown]
# <a href="https://colab.research.google.com/github/CopotronicRifat/CV-Tools/blob/main/LAMBDA_PLOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = [0.00, 0.05, 0.1, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.55, 0.60, 0.65, 0.70, 0.75, 0.80, 0.85, 0.90, 0.95, 1.0]
y = [73, 78, 83, 92, 94, 90, 81, 75, 63, 55, 53, 52, 49, 44, 42, 41, 40, 38, 37, 34, 32]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10,10))

plt.plot(x, y, "o-")
  
plt.xlabel('λ value')
plt.ylabel('Testing Accuracy (%)')
plt.title('Adversarial weights controller parameter, λ')
plt.grid(True)
  
plt.show()
